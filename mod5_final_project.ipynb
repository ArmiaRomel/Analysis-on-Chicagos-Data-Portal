# %%
import sqlite3
import pandas as pd

con = sqlite3.connect('FinalDB.db')
cur = con.cursor()

# %%
# %load_ext sql

# %%
census = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
crime = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
public = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')

census.to_sql('ChicagoCensusData', con, if_exists='replace', index=False, method='multi')
crime.to_sql('ChicagoCrimeData', con, if_exists='replace', index=False, method='multi')
public.to_sql('ChicagoPublicSchools', con, if_exists='replace', index=False, method='multi')

# %%
# %sql sqlite:///FinalDB.db
# Out:
# 'Connected: @FinalDB.db'

# %%
# %sql SELECT * FROM CENSUS_DATA LIMIT 2;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0)]

# %%
# %sql SELECT * FROM CHICAGO_PUBLIC_SCHOOLS LIMIT 2;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.4579999999, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(3512276, 'HK587712', '2004-08-28', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.807440500000006, -87.70395585, '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '2004-06-26', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '2011-04-04', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
#  (7903289, 'HT133522', '2010-12-30', '083XX S KINGSTON AVE', '840', 'THEFT', 'FINANCIAL ID THEFT: OVER $300', 'RESIDENCE', 0, 0, 423, 4, 7.0, 46.0, '6', 1194622.0, 1850125.0, 2010, 41.74366532, -87.56246276, '(41.743665322, -87.562462756)'),
# ...

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %%
# %sql SELECT COMMUNITY_AREA_NAME, COMMUNITY_AREA_NUMBER, PER_CAPITA_INCOME FROM CENSUS_DATA \
        WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park', 26.0, 10934),
#  ('South Lawndale', 30.0, 10402),
#  ('Fuller Park', 37.0, 10432),
#  ('Riverdale', 54.0, 8201)]

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(3987219, 'HL266884', '2005-03-31', '024XX N CLARK ST', '2210', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 'CONVENIENCE STORE', 1, 0, 2333, 19, 43.0, 7.0, '22', 1172680.0, 1916483.0, 2005, 41.92626872, -87.64089934, '(41.926268719, -87.640899336)'),
#  (3266814, 'HK238408', '2004-03-13', '093XX S STONY ISLAND AVE', '2230', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 'ALLEY', 1, 0, 413, 4, 8.0, 48.0, '22', 1188539.0, 1843379.0, 2004, 41.72530099, -87.58496589, '(41.72530099, -87.584965887)')]

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'KIDNAPPING';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
# %sql SELECT DISTINCT PRIMARY_TYPE FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION like '%SCHOOL%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
# %sql SELECT `Elementary, Middle, or High School`, AVG(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS \
        GROUP BY `Elementary, Middle, or High School`;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
# %%sql
#
# SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(54.0, 'Riverdale', 56.5),
#  (37.0, 'Fuller Park', 51.2),
#  (68.0, 'Englewood', 46.6),
#  (29.0, 'North Lawndale', 43.1),
#  (27.0, 'East Garfield Park', 42.4)]

# %%
# %%sql SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS Number_of_incidents FROM CHICAGO_CRIME_DATA
#         GROUP BY COMMUNITY_AREA_NUMBER
#         ORDER BY Number_of_incidents DESC LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0, 43)]

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %%
# %%sql
# SELECT CD.COMMUNITY_AREA_NAME, (SELECT COMMUNITY_AREA_NUMBER FROM CHICAGO_CRIME_DATA
#                                     GROUP BY COMMUNITY_AREA_NUMBER
#                                     ORDER BY COUNT(*) DESC LIMIT 1)
# FROM CHICAGO_CRIME_DATA CCA, CENSUS_DATA CD
# WHERE CD.COMMUNITY_AREA_NUMBER = CCA.COMMUNITY_AREA_NUMBER;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Brighton Park', 25.0),
#  ('Humboldt park', 25.0),
#  ('Grand Boulevard', 25.0),
#  ('South Chicago', 25.0),
#  ('Chicago Lawn', 25.0),
#  ('West Town', 25.0),
#  ('Albany Park', 25.0),
#  ('Grand Boulevard', 25.0),
#  ('Beverly', 25.0),
#  ('Avondale', 25.0),
#  ('West Lawn', 25.0),
#  ('Near West Side', 25.0),
#  ('Roseland', 25.0),
#  ('Near West Side', 25.0),
#  ('West Garfield Park', 25.0),
#  ('Logan Square', 25.0),
#  ('Calumet Heights', 25.0),
#  ('Chatham', 25.0),
#  ('Austin', 25.0),
#  ('Austin', 25.0),
#  ('Near North Side', 25.0),
#  ('Loop', 25.0),
#  ('Greater Grand Crossing', 25.0),
#  ('McKinley Park', 25.0),
#  ('Englewood', 25.0),
#  ('Albany Park', 25.0),
#  ("O'Hare", 25.0),
#  ('Chicago Lawn', 25.0),
#  ('Washington Height', 25.0),
#  ('Chatham', 25.0),
#  ('Loop', 25.0),
#  ('Douglas', 25.0),
#  ('Lake View', 25.0),
#  ('South Lawndale', 25.0),
#  ('Humboldt park', 25.0),
#  ('Englewood', 25.0),
# ...
